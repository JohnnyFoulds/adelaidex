# %% [markdown]
# # Section 3 : Quiz 6
#
# ## Web References
#
# - [SciPy – Cluster Hierarchy Dendrogram](https://www.geeksforgeeks.org/scipy-cluster-hierarchy-dendrogram/)
# - [scipy.cluster.hierarchy.dendrogram](https://docs.scipy.org/doc/scipy/reference/generated/scipy.cluster.hierarchy.dendrogram.html)
# - [Cutting SciPy hierarchical dendrogram into clusters via a threshold value](https://stackoverflow.com/questions/28687882/cutting-scipy-hierarchical-dendrogram-into-clusters-via-a-threshold-value)
# - [scipy linkage format](https://stackoverflow.com/questions/9838861/scipy-linkage-format/10956285#10956285)

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

import scipy
from scipy.cluster.hierarchy import dendrogram, linkage
#from scipy.cluster.hierarchy import fcluster
#from scipy.cluster.hierarchy import cophenet
from scipy.spatial.distance import pdist
from scipy.spatial.distance import euclidean

# %% [markdown]
# ## Configure Output Settings

# %%
#np.set_printoptions(precision=4, suppress=True)

# %% [markdown]
# ## Figure out scipy linkage format

# %% [markdown]
# ### Using Linkage

# %%
#data = np.array([0, 1, 3, 7, 10, 14])
data = np.array([[0], [1], [3], [7], [10], [14]])

data_linkage = linkage(data, method='single')
print(data_linkage)

plt.figure() 
dn = dendrogram(data_linkage, labels=data)
#dn = dendrogram(data_linkage, labels=['a', 'b', 'c', 'd'])
# Out:
# [[0. 1. 1. 2.]
#  [2. 6. 2. 3.]
#  [3. 4. 3. 2.]
#  [7. 8. 4. 5.]
#  [5. 9. 4. 6.]]
# /usr/local/lib/python3.8/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %% [markdown]
# ### Custom Clustering

# %%
data = np.array([0, 1, 3, 7, 10, 14])

# %% [markdown]
# ## Data Load

# %%
data = np.array([0,1,3,7,10,14,16,24,30])

x = np.array([0, 1, 3])

# %%
y = np.random.rand(15, 12)
y
# Out:
# array([[0.6116819 , 0.22886025, 0.02952294, 0.02185435, 0.89789442,
#         0.79277256, 0.88866338, 0.70930101, 0.64111261, 0.35002378,
#         0.15142839, 0.83920947],
#        [0.19891319, 0.63770831, 0.13298566, 0.51821363, 0.44716445,
#         0.93917754, 0.87190315, 0.97018667, 0.46568517, 0.02183447,
#         0.73136863, 0.8557132 ],
#        [0.03963879, 0.58052068, 0.06253049, 0.38645689, 0.86247007,
#         0.47710187, 0.70476482, 0.86222603, 0.87805212, 0.64131651,
#         0.06292194, 0.38362776],
#        [0.11138385, 0.65309549, 0.136117  , 0.50653524, 0.2392073 ,
#         0.56207993, 0.10475989, 0.20897849, 0.93181039, 0.04881096,
#         0.16815856, 0.80062483],
#        [0.8623623 , 0.03246699, 0.12185582, 0.14711397, 0.32824576,
#         0.84119029, 0.71344112, 0.02001667, 0.97002392, 0.21029434,
#         0.4422264 , 0.75069883],
#        [0.30381763, 0.55832186, 0.7026693 , 0.90039741, 0.13805263,
#         0.66104436, 0.15214037, 0.44650838, 0.03537267, 0.57941618,
#         0.56559511, 0.63033325],
#        [0.28984164, 0.45045682, 0.28875935, 0.24827641, 0.02576511,
#         0.05079501, 0.88936273, 0.35349257, 0.86642442, 0.9997549 ,
#         0.42449   , 0.50958602],
#        [0.4865586 , 0.31493752, 0.70477217, 0.4921244 , 0.80575728,
#         0.86636397, 0.40804243, 0.61906432, 0.25043803, 0.65658366,
#         0.11307262, 0.89995271],
#        [0.41014125, 0.03490701, 0.19623587, 0.43130086, 0.78379993,
#         0.05068853, 0.85947971, 0.76811691, 0.94630746, 0.61519853,
#         0.46582739, 0.82874651],
#        [0.48839003, 0.49717308, 0.78665016, 0.86912995, 0.30432844,
#         0.97010656, 0.95787055, 0.19750531, 0.62014956, 0.77651154,
#         0.88567695, 0.13195194],
#        [0.63363543, 0.48209275, 0.69674906, 0.33057542, 0.7293133 ,
#         0.09687281, 0.06866293, 0.17708604, 0.4546909 , 0.54690869,
#         0.65901328, 0.67200801],
#        [0.76127853, 0.64692982, 0.99131323, 0.12465816, 0.59156552,
#         0.11979058, 0.37212967, 0.94237443, 0.72317474, 0.21487987,
#         0.6269964 , 0.20949332],
#        [0.95007281, 0.47966898, 0.88664909, 0.40089354, 0.2035413 ,
#         0.96059635, 0.26861613, 0.98647534, 0.50100854, 0.3981806 ,
#         0.18405763, 0.87701483],
#        [0.08292126, 0.24948559, 0.85966127, 0.55317645, 0.27580811,
#         0.13489691, 0.58662756, 0.43613628, 0.53988019, 0.11188267,
#         0.67621332, 0.29227092],
#        [0.04157961, 0.30386951, 0.14366893, 0.65029252, 0.63694436,
#         0.59133324, 0.85402993, 0.09528151, 0.67317891, 0.57603115,
#         0.83996773, 0.39194904]])

# %%
euclidean([0,7], 1)
# Out:
# 6.082762530298219

# %% [markdown]
# ## Generate Dendrograms

# %%
data = np.array([[0], [1], [3], [7], [10], [14], [16], [24], [30]])
data_linkage = linkage(data, method='centroid')
print(data_linkage)
d = dendrogram(data_linkage, count_sort='descending', labels=data)
# Out:
# [[ 0.          1.          1.          2.        ]
#  [ 5.          6.          2.          2.        ]
#  [ 2.          9.          2.5         3.        ]
#  [ 3.          4.          3.          2.        ]
#  [ 7.          8.          6.          2.        ]
#  [10.         12.          6.5         4.        ]
#  [11.         14.         10.41666667  7.        ]
#  [13.         15.         19.71428571  9.        ]]

# %%
data_linkage = linkage(data, method='single')
print(data_linkage)
d = dendrogram(data_linkage, count_sort='descending', labels=data)
# Out:
# [[ 0.  1.  1.  2.]
#  [ 2.  9.  2.  3.]
#  [ 5.  6.  2.  2.]
#  [ 3.  4.  3.  2.]
#  [10. 12.  4.  5.]
#  [11. 13.  4.  7.]
#  [ 7.  8.  6.  2.]
#  [14. 15.  8.  9.]]
