# %% [markdown]
# # Activity 2

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import igraph as ig
import numpy as np

# %% [markdown]
# ## Data Load

# %%
df_nodes = pd.read_csv('ca-netscience.mis', skiprows=1, delimiter=' ', header=None, names=['edge', 'node1', 'node2'])
del df_nodes['edge']
df_nodes.head()
# Out:
#    node1  node2
# 0      2      1
# 1      3      1
# 2      4      1
# 3      5      1
# 4     16      1

# %% [markdown]
# ## Create Graph

# %%
node_tuples = [tuple(x) for x in df_nodes.values]
net_graph = ig.Graph.TupleList(node_tuples, directed=False)
ig.summary(net_graph)
# Out:
# IGRAPH UN-- 379 914 --
# + attr: name (v)

# %% [markdown]
# ## Plot Graph

# %%
ig.plot(net_graph, vertex_label=net_graph.vs["name"])
